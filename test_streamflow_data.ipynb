# %%
import gzip as gz
import dask.dataframe as dd
import pandas as pd

# %%
f=gzip.open('dv.gz')

# %%
df = pd.read_csv("dv.gz", error_bad_lines=False)
df
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_11196\3907797370.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("dv.gz", error_bad_lines=False)
# ...

# %%
df[15000:15020]
# Out:
#       # ---------------------------------- WARNING ----------------------------------------
# 15000                USGS\t01605500\t2020-12-24\t1030\tA
# 15001              USGS\t01605500\t2020-12-25\t2090\tA:e
# 15002                 USGS\t01605500\t2020-12-26\t763\tA
# 15003                 USGS\t01605500\t2020-12-27\t526\tA
# 15004                 USGS\t01605500\t2020-12-28\t426\tA
# 15005                 USGS\t01605500\t2020-12-29\t359\tA
# 15006                 USGS\t01605500\t2020-12-30\t301\tA
# 15007                 USGS\t01605500\t2020-12-31\t285\tA
# 15008                                                  #
# 15009                  # Data provided for site 01606000
# 15010  #            TS   parameter     statistic     ...
# 15011                                                  #
# 15012  # Data-value qualification codes included in t...
# 15013                                          #
# 15014  #     A  Approved for publication -- Processin...
# ...

# %%
df[15019:30019]
# Out:
#       # ---------------------------------- WARNING ----------------------------------------
# 15019                 USGS\t01606000\t1980-01-01\t327\tA
# 15020                 USGS\t01606000\t1980-01-02\t286\tA
# 15021                 USGS\t01606000\t1980-01-03\t253\tA
# 15022                 USGS\t01606000\t1980-01-04\t235\tA
# 15023                 USGS\t01606000\t1980-01-05\t228\tA
# ...                                                  ...
# 30014                 USGS\t01606500\t1980-01-10\t349\tA
# 30015                 USGS\t01606500\t1980-01-11\t353\tA
# 30016                 USGS\t01606500\t1980-01-12\t766\tA
# 30017                 USGS\t01606500\t1980-01-13\t774\tA
# 30018                USGS\t01606500\t1980-01-14\t1110\tA
#
# [15000 rows x 1 columns]

# %%
df = pd.read_csv("monthly.gz", error_bad_lines=False)
df
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_11196\228256883.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("monthly.gz", error_bad_lines=False)
# ...

# %%
df.loc[21]
# Out:
# #    USGS\t02160500\tENOREE RIVER NEAR ENOREE S. C.
# Name: 21, dtype: object

# %%
Link = https://waterdata.usgs.gov/nwis/monthly?referred_module=sw&site_tp_cd=ST&nw_longitude_va=84&nw_latitude_va=39&se_longitude_va=79&se_latitude_va=34&coordinate_format=decimal_degrees&dvstat_count_nu=15000&index_pmcode_00060=1&group_key=NONE&sitefile_output_format=rdb_gz&column_name=agency_cd&column_name=site_no&column_name=station_nm&format=sites_selection_links&list_of_search_criteria=lat_long_bounding_box%2Csite_tp_cd%2Cobs_count_nu%2Crealtime_parameter_selection
